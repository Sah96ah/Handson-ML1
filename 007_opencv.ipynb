# %% [markdown]
# Installing opencv

# %%
# !pip install opencv-python
# !pip install opencv-contrib-python

# %% [markdown]
# *Useful computer vision library*
# 1. OpenCV
# 2. PIL
# 3. Sci-kit image
# 4. Mahotas
# *other libraries*
# 1. Sci-py
# 2. Numpy
# 3. Matplotlib
# 4. Imutils
# 5. Wheel

# %% [markdown]
# Read image

# %%
import cv2
import imutils
import matplotlib.pyplot as plt

# %%
img = cv2.imread("Data/dog.jpg")
plt.imshow(img)
img.ndim
# Out:
# 3

# %%
resized_image = imutils.resize(img, width=300, height=400)
cv2.imshow("dog image", resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Image preprocessing
